# %% [markdown]
# ## Generating Blobs Problem
# To manipulate the center of the cluster use the property of ```cluster_std```

# %%
from sklearn.datasets.samples_generator import make_blobs
from matplotlib import pyplot
from pandas import DataFrame

X, y = make_blobs(n_samples=100, centers=2, cluster_std=1.0, n_features=2)
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue'}
fix, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y',
               label=key, color=colors[key])
pyplot.show()

# %% [markdown]
# ## Creating Moons Datasets

# %%
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, noise=0.2)
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
fix, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y',
               label=key, color=colors[key])
pyplot.show()

df
# Out:
#     label         x         y
# 0       1 -0.167973  0.588052
# 1       1 -0.043685  0.419581
# 2       1  0.598566 -0.304388
# 3       0 -0.295686  0.928489
# 4       1  0.046029 -0.091521
# 5       1  2.084411  0.143977
# 6       0  1.195165  0.163820
# 7       1 -0.046967  0.122776
# 8       0 -0.458893  1.006924
# 9       0  0.935003  0.214043
# 10      0 -0.497318  0.211174
# 11      0  0.136574  0.933067
# 12      1  2.167702  0.695823
# 13      1  1.723334 -0.032104
# 14      1  2.052038  0.595367
# 15      1  0.336544 -0.226404
# 16      1  1.606871 -0.246869
# 17      0 -1.082425  0.784543
# 18      1  0.423595 -0.378803
# 19      1  1.996647 -0.426565
# 20      1  0.571568 -0.247797
# 21      1  1.784438  0.151460
# 22      0  0.356352  1.199024
# 23      1  0.402835  0.265499
# 24      0  0.199367  1.257499
# 25      0  0.843732  0.096776
# 26      0 -0.973455  0.206565
# 27      1  1.955209  0.081206
# 28      0 -0.298970  0.573210
# 29      0  0.630696  0.813138
# ..    ...       ...       ...
# 70      1  0.403920  0.430126
# 71      1  1.265546 -0.258522
# 72      0 -0.517354 -0.008457
# 73      0  0.005688  1.088250
# 74      0 -0.602274  0.485387
# 75      1  1.898557 -0.083843
# 76      1 -0.036615 -0.370000
# 77      0 -1.297914  0.193964
# 78      0 -0.864148 -0.004583
# 79      0  0.598884  0.706702
# 80      1  0.465601 -0.558217
# 81      0  0.802996  0.285614
# 82      0 -0.206807  1.205871
# 83      1  0.957410 -0.461321
# 84      0  0.558546  0.554612
# 85      1  2.104401  0.263399
# 86      1  2.142667 -0.015105
# 87      0 -0.793137 -0.045731
# 88      0 -0.775329  0.275579
# 89      0  0.745443  0.532462
# 90      0  0.866756  0.446777
# 91      1  0.395394 -0.708827
# 92      0  1.009842  0.655266
# 93      0 -0.034479  0.830213
# 94      1  1.082554 -0.249860
# 95      0 -0.110769  1.033734
# 96      0  1.149621 -0.319373
# 97      1  1.134321 -0.440076
# 98      1  0.755968 -0.632112
# 99      1  0.870521 -0.556332
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Creating Circles

# %%
from sklearn.datasets import make_circles
from matplotlib import pyplot
from pandas import DataFrame
# generate 2d classification dataset
X, y = make_circles(n_samples=100, noise=0.15)
# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()
