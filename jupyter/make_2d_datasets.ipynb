# %% [markdown]
# ## Generating Blobs Problem
# To manipulate the center of the cluster use the property of ```cluster_std```

# %%
from sklearn.datasets.samples_generator import make_blobs
from matplotlib import pyplot
from pandas import DataFrame

X, y = make_blobs(n_samples=100, centers=2, cluster_std=1.0, n_features=2)
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue'}
fix, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y',
               label=key, color=colors[key])
pyplot.show()

# %% [markdown]
# ## Creating Moons Datasets

# %%
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, noise=0.1)
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
fix, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y',
               label=key, color=colors[key])
pyplot.show()

df
# Out:
#     label         x         y
# 0       0 -0.778947  0.375283
# 1       0 -0.905663  0.356495
# 2       0  0.426626  0.651313
# 3       1  0.840445 -0.577570
# 4       1  1.770116 -0.023485
# 5       1  0.117373  0.235357
# 6       1  0.211712 -0.003634
# 7       0 -0.633802  0.787824
# 8       1  0.417789 -0.299810
# 9       1  1.561658 -0.295953
# 10      0  0.908091  0.172990
# 11      1  1.939820  0.355701
# 12      1  1.953216  0.301943
# 13      1  0.763585 -0.549453
# 14      0 -0.309069  0.932699
# 15      1  0.714790 -0.487318
# 16      0  0.398525  0.903656
# 17      1  0.218944  0.215047
# 18      1  0.554653 -0.204069
# 19      0 -0.816733  0.814363
# 20      0  0.936578  0.453271
# 21      0 -0.807960  0.862974
# 22      0  0.728815  0.647143
# 23      1  0.111239  0.152141
# 24      0 -0.221195  0.957893
# 25      1  0.065039  0.367522
# 26      0 -1.017784  0.056266
# 27      0  0.847125  0.508464
# 28      1  0.576968 -0.191413
# 29      0  0.978773 -0.027138
# ..    ...       ...       ...
# 70      1  0.541072 -0.385987
# 71      0  0.988405 -0.036148
# 72      1  0.325842 -0.030006
# 73      0 -0.290914  0.806418
# 74      1  1.829069  0.462425
# 75      0  0.571889  0.940661
# 76      0 -0.143704  0.997349
# 77      1  1.658560 -0.102651
# 78      0  0.659780  0.846272
# 79      1  1.076476 -0.479422
# 80      0  0.801995  0.348707
# 81      0  0.078173  0.996706
# 82      1  0.508917 -0.397976
# 83      1  1.967649  0.563303
# 84      1  2.064888  0.148578
# 85      1  1.153953 -0.467685
# 86      1  1.654736 -0.221325
# 87      1  1.992921 -0.020970
# 88      0  0.031108  1.026388
# 89      0 -0.038427  1.025195
# 90      1  1.599645 -0.371211
# 91      1  0.002479  0.354561
# 92      0 -0.379049  0.778792
# 93      0  0.308006  0.883051
# 94      1  1.998153  0.184042
# 95      0 -0.859684  0.553554
# 96      1  1.063334 -0.587899
# 97      0  0.705152  0.556467
# 98      0  1.156272  0.294628
# 99      1  1.952332 -0.102532
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Creating Circles

# %%
from sklearn.datasets import make_circles
from matplotlib import pyplot
from pandas import DataFrame
# generate 2d classification dataset
X, y = make_circles(n_samples=100, noise=0.05)
# scatter plot, dots colored by class value
df = DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()
